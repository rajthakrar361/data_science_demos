# %% [markdown]
# # This is Demo Notebook
# ### It was created by Raj Thakrar on 2nd of August.
# ##### It uses a python kernal and also has some python code!

# %%
one = 1
two = 2
third_num = input("Please enter a number - ")
print(one + two + third_num);
